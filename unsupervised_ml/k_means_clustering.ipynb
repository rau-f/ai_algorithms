# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# generate fake clustered data
X, _ = make_blobs(n_samples=300, centers=5, random_state=42)

# train
model = KMeans(n_clusters=5, random_state=42)
model.fit(X)

# results
print(model.labels_)        # which cluster each point belongs to
print(model.cluster_centers_) # centroid coordinates

# plot
plt.scatter(X[:, 0], X[:, 1], c=model.labels_)
plt.scatter(model.cluster_centers_[:, 0], model.cluster_centers_[:, 1], 
            c='red', marker='x', s=200)
plt.show()
# Out:
# [3 0 3 0 3 4 0 2 1 0 0 3 0 3 0 3 0 0 0 3 3 0 3 0 0 3 2 0 0 2 1 0 0 1 2 0 0
#  0 4 0 3 0 2 1 0 1 3 2 0 2 4 0 2 1 3 1 0 3 4 2 3 4 0 0 2 0 2 2 2 2 0 2 4 0
#  4 3 4 1 0 3 2 3 3 0 3 2 4 0 0 0 0 0 3 0 3 3 0 1 0 0 4 4 0 2 3 3 3 0 3 0 4
#  0 0 0 3 3 3 2 4 1 4 2 1 1 3 2 0 0 4 3 0 1 0 3 3 3 3 0 2 0 3 4 3 0 0 3 0 2
#  0 2 0 2 2 0 3 0 2 4 3 0 1 1 0 0 3 1 0 0 0 0 2 3 0 0 3 0 4 0 2 2 4 1 0 2 2
#  0 3 1 2 0 0 2 3 2 2 1 4 2 0 0 1 2 0 0 1 3 3 2 2 3 2 1 0 2 3 0 1 1 2 0 1 4
#  0 4 0 0 1 0 4 0 1 0 0 2 0 0 0 0 0 3 4 0 2 0 2 1 0 0 2 2 0 0 4 2 4 0 2 0 2
#  0 2 3 0 0 0 3 0 0 2 0 1 2 2 3 3 4 0 0 0 0 1 3 3 0 0 2 2 2 0 0 4 0 2 4 3 4
#  2 3 0 3]
# [[ 3.26972454  3.11413579]
#  [-8.05313434  6.76835691]
#  [-6.68626728 -6.96943511]
#  [-2.64588966  8.93756574]
#  [-9.58882438  7.7981948 ]]

# %%
import matplotlib.pyplot as plt

# basic line plot
plt.plot([1,2,3,4], [1,4,9,16])
plt.title("title")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# scatter plot
plt.scatter([1,2,3,4], [1,4,9,16])
plt.show()

# bar chart
plt.bar(['a','b','c'], [10,20,15])
plt.show()

# multiple plots
plt.plot([1,2,3], label='line1')
plt.plot([3,2,1], label='line2')
plt.legend()
plt.show()

# color and marker
plt.scatter(x, y, c='red', marker='x', s=200)  # c=color, s=size
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 25
#      22 plt.show()
#      24 # color and marker
# ---> 25 plt.scatter(x, y, c='red', marker='x', s=200)  # c=color, s=size
#
# NameError: name 'x' is not defined

# %%
plt.plot([1,2,3], label='train loss')
plt.plot([3,2,1], label='test loss')
plt.legend()  # shows box with "train loss" and "test loss"
plt.show()
